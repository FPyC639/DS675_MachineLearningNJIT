# %% [markdown]
# Hoeffding's Bound Inequality
# \begin{equation}
# \mathbb{P}[|E_{in}(g)-E_{out}(g)|\gt ϵ]\le 2Me^{-2ϵN}
# \end{equation}

# %% [markdown]
# #Question 1

# %% [markdown]
# ## (a)
# # Equation 1: Error Bound
#
# \begin{equation}
#   \sqrt{\frac{1}{2N}\cdot \mathbf{ln}(\frac{2M}{\delta})}
# \end{equation}
#
# # Substitution
#
# \begin{equation}
#   \sqrt{\frac{1}{2(600)}\cdot \mathbf{ln}(\frac{2\cdot (1000)}{(0.05)})}=9.397 \cdot 10^{-2}
# \end{equation}
#
# The full Error Bar is given as follows:
#
# \begin{equation}
#   E_{out} \le E_{in} + \sqrt{\frac{1}{2(600)}\cdot \mathbf{ln}(\frac{2\cdot (1000)}{(0.05)})}
# \end{equation}
# ## (b)
# This will cause the variance to rise which is not what we want. We want to find balance and examine the error where every parameter is at its minimum.

# %% [markdown]
# #Question 2

# %% [markdown]
# ## (a)
# # Equation 2 : Growth Function
# - $X = \mathbb{R}\text{(one dimensional)}$
# - $\mathcal{H} \text{ contains h, where each h(x) = sign(x - a) for threshold a}$
# - $\text{one dichotomy for } a \in  \text{(} x_n,x_{n+1} \text{)}:$
#
# \begin{equation}
#   {m_{H}(N) \leq N + 1}
# \end{equation}
#
# which is the maximum number of dichotomies for $\text{positive rays}$
#
# OR
# \begin{equation}
#   {m_{H}(N) \leq N + 1}
# \end{equation}
#
# which is the maximum number of dichotomies for $\text{negative rays}$
#
# Considering both positive or negative rays the maximum number of dichotomies:
# \begin{equation}
#   {m_{H}(N) \leq (N + 1) + (N+1)}
# \end{equation}
# \begin{equation}
#   {\leq (-∞,a] ∪ [a, ∞)}
# \end{equation}
# \begin{equation}
#   {\leq \mathbf{set_W} + \mathbf{set_V}; \text{ where } \mathbf{set_W} = (-∞,a] \text{ and } \mathbf{set_V} = [a, ∞)}
# \end{equation}
# \begin{equation}
#   {\leq \mathbf{set_W} + \mathbf{set_V} - (\mathbf{set_W} ∩  set_V)}
# \end{equation}
# \begin{equation}
#   {\leq (-∞,a] + [a, \infty] - [(-∞,a]  \cap [a, ∞)]}
# \end{equation}
# \begin{equation}
#   {\leq (-∞, ∞)}
# \end{equation}
# \begin{equation}
#   {\leq 2(N+1)}
# \end{equation}
# <!--
# - $X = \mathbb{R}\text{(one dimensional)}$
# - $\mathcal{H} \text{ contains h, where each h(x) = sign(x - a) for threshold a}$
# - $\text{one dichotomy for } a \in  \text{(} x_n,x_{n+1} \text{)}:$
#
# \begin{equation}
#   {m_{H}(N) \leq N + 1}
# \end{equation}
#
# which is the maximum number of dichotomies for $\text{positive rays}$
#
# So, in our case the maximum number of dichtomies is
# \begin{equation}
#   {m_{H}(\infty) \leq \infty +1}
# \end{equation}
#
# AND
# \begin{equation}
#   (N+1) \ll 2^N ; N = ∞
# \end{equation} -->
#
# ## (b)
# The circumstance that one is given in the problem is the Real Number Line therefore the VC-dimension is infinty.
# ${m_h(N)=2^N \text{ for all N, then } d_{vc}(H) = ∞}$

# %% [markdown]
# # Question 3

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function
def f(x, y):
    return x**2 + 2*y**2 + 2*np.sin(2*np.pi*x)*np.sin(2*np.pi*y)
def gradient_descent_Jose(learning_rate, num_iterations):
    x = np.linspace(0,.1,num=num_iterations)
    y = np.linspace(0,.1,num=num_iterations)
    X, Y = np.meshgrid(x, y)
    df_dx, df_dy =  np.gradient(f(X,Y), x, y )
    z = []
    for i in range(num_iterations):
        #x -= learning_rate * df_dx
        #y -= learning_rate * df_dy
        # Update x and y using gradient descent
        x -= learning_rate * df_dx[0]
        y -= learning_rate * df_dy[0]
        z.append(f(x, y))


    return x, y, z
learning_rate_1 = 0.01
learning_rate_2 = 0.1
num_iterations = 50

# Perform gradient descent
x1, y1, history1 = gradient_descent_Jose(learning_rate_1, num_iterations)
x2, y2, history2 = gradient_descent_Jose(learning_rate_2, num_iterations)

# Plot the convergence
iterations = list(range(1, num_iterations + 1))
plt.figure(figsize=(12, 6))
plt.plot(iterations, history1[0], label='η = 0.01', marker='o', linestyle='-', color='b')
plt.plot(iterations, history2[0], label='η = 0.1', marker='x', linestyle='--', color='r')
plt.xlabel('Iterations')
plt.ylabel('Function Value')
plt.legend()
plt.title('Gradient Descent Convergence')
plt.grid(True)
plt.show()
plt.figure(figsize=(12, 6))

# %%
# Gradient of the function
def gradient_f(x, y):
    df_dx = 2*x + 4*np.pi*np.cos(2*np.pi*x)*np.sin(2*np.pi*y)
    df_dy = 4*y + 4*np.pi*np.sin(2*np.pi*x)*np.cos(2*np.pi*y)
    return df_dx, df_dy
# Define a function for gradient descent
def gradient_descent_with_starting_point(learning_rate, num_iterations, start_point):
    x, y = start_point
    history = []  # Store function values for plotting

    for i in range(num_iterations):
        df_dx, df_dy = gradient_f(x, y)
        x -= learning_rate * df_dx
        y -= learning_rate * df_dy
        history.append(f(x, y))

    return x, y, history

# List of initial points
initial_points = [(0.1, 0.1), (1, 1), (-0.5, -0.5), (-1, -1)]

# Perform gradient descent for each initial point
results = []
for start_point in initial_points:
    x, y, history = gradient_descent_with_starting_point(learning_rate_1, num_iterations, start_point)
    min_value = f(x, y)
    results.append((start_point, (x, y), min_value))

# Print results in a table
print("Initial Point     Minimum Location    Minimum Value")
for start_point, (x, y), min_value in results:
    print(f"{start_point}        ({x:.4f}, {y:.4f})        {min_value:.4f}")
# Out:
# Initial Point     Minimum Location    Minimum Value
# (0.1, 0.1)        (0.2438, -0.2379)        -1.8201
# (1, 1)        (1.2181, 0.7128)        0.5933
# (-0.5, -0.5)        (-0.7314, -0.2379)        -1.3325
# (-1, -1)        (-1.2181, -0.7128)        0.5933

# %% [markdown]
# # Question 4

# %% [markdown]
# The bias variance trade off allows one to note that the increasing of the validation set test size one can better approximate the out-of-sample error since bias nears 0.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !sudo apt-get install texlive-xetex texlive-fonts-recommended texlive-plain-generic
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   dvisvgm fonts-droid-fallback fonts-lato fonts-lmodern fonts-noto-mono
#   fonts-texgyre fonts-urw-base35 libapache-pom-java libcommons-logging-java
#   libcommons-parent-java libfontbox-java libfontenc1 libgs9 libgs9-common
#   libidn12 libijs-0.35 libjbig2dec0 libkpathsea6 libpdfbox-java libptexenc1
#   libruby3.0 libsynctex2 libteckit0 libtexlua53 libtexluajit2 libwoff1
#   libzzip-0-13 lmodern poppler-data preview-latex-style rake ruby
#   ruby-net-telnet ruby-rubygems ruby-webrick ruby-xmlrpc ruby3.0
#   rubygems-integration t1utils teckit tex-common tex-gyre texlive-base
#   texlive-binaries texlive-latex-base texlive-latex-extra
#   texlive-latex-recommended texlive-pictures tipa xfonts-encodings
#   xfonts-utils
# Suggested packages:
#   fonts-noto fonts-freefont-otf | fonts-freefont-ttf libavalon-framework-java
# ...

# %%
# !jupyter nbconvert --to pdf /content/drive/MyDrive/SerraJoseAssignment3.ipynb
# Out:
# [NbConvertApp] Converting notebook /content/drive/MyDrive/SerraJoseAssignment3.ipynb to pdf
# [NbConvertApp] Support files will be in SerraJoseAssignment3_files/
# [NbConvertApp] Making directory ./SerraJoseAssignment3_files
# [NbConvertApp] Writing 67626 bytes to notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', 'notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: ['bibtex', 'notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 114619 bytes to /content/drive/MyDrive/SerraJoseAssignment3.pdf
